# %% [markdown]
# # Open and clean data
# ## Sheet 1: Team name and conference info
#
# Note that I've added a column `team_id`. That's how I'm going to refer to each team (for indexing purposes)

# %%
import pandas as pd
import numpy as np

teams_divisions=pd.read_excel('Analytics_Attachment.xlsx', sheetname=0)
teams_divisions['team_id'] = np.array([i for i in range(30)])
teams_divisions
# Out:
#                  Team_Name Division_id Conference_id  team_id
# 0           Boston Celtics    Atlantic          East        0
# 1            Brooklyn Nets    Atlantic          East        1
# 2          New York Knicks    Atlantic          East        2
# 3       Philadelphia 76ers    Atlantic          East        3
# 4          Toronto Raptors    Atlantic          East        4
# 5            Chicago Bulls     Central          East        5
# 6      Cleveland Cavaliers     Central          East        6
# 7          Detroit Pistons     Central          East        7
# 8           Indiana Pacers     Central          East        8
# 9          Milwaukee Bucks     Central          East        9
# 10           Atlanta Hawks   Southeast          East       10
# 11       Charlotte Hornets   Southeast          East       11
# 12              Miami Heat   Southeast          East       12
# 13           Orlando Magic   Southeast          East       13
# 14      Washington Wizards   Southeast          East       14
# 15          Denver Nuggets   Northwest          West       15
# 16  Minnesota Timberwolves   Northwest          West       16
# 17   Oklahoma City Thunder   Northwest          West       17
# 18  Portland Trail Blazers   Northwest          West       18
# 19               Utah Jazz   Northwest          West       19
# 20   Golden State Warriors     Pacific          West       20
# 21             LA Clippers     Pacific          West       21
# 22      Los Angeles Lakers     Pacific          West       22
# 23            Phoenix Suns     Pacific          West       23
# 24        Sacramento Kings     Pacific          West       24
# 25        Dallas Mavericks   Southwest          West       25
# 26         Houston Rockets   Southwest          West       26
# 27       Memphis Grizzlies   Southwest          West       27
# 28    New Orleans Pelicans   Southwest          West       28
# 29       San Antonio Spurs   Southwest          West       29

# %% [markdown]
# ## Sheet 2: Game Results
#
# First, open the data file. It's not really in a usable format yet, so we will clean it a bit.

# %%
results=pd.read_excel('Analytics_Attachment.xlsx', sheetname=1)

results
# Out:
#            Date               Home Team               Away Team  Home Score  \
# 0    2016-10-25     Cleveland Cavaliers         New York Knicks         117
# 1    2016-10-25  Portland Trail Blazers               Utah Jazz         113
# 2    2016-10-25   Golden State Warriors       San Antonio Spurs         100
# 3    2016-10-26           Orlando Magic              Miami Heat          96
# 4    2016-10-26          Indiana Pacers        Dallas Mavericks         130
# 5    2016-10-26          Boston Celtics           Brooklyn Nets         122
# 6    2016-10-26         Toronto Raptors         Detroit Pistons         109
# 7    2016-10-26         Milwaukee Bucks       Charlotte Hornets          96
# 8    2016-10-26       Memphis Grizzlies  Minnesota Timberwolves         102
# 9    2016-10-26    New Orleans Pelicans          Denver Nuggets         102
# 10   2016-10-26      Philadelphia 76ers   Oklahoma City Thunder          97
# 11   2016-10-26            Phoenix Suns        Sacramento Kings          94
# 12   2016-10-26      Los Angeles Lakers         Houston Rockets         120
# 13   2016-10-27           Atlanta Hawks      Washington Wizards         114
# 14   2016-10-27           Chicago Bulls          Boston Celtics         105
# 15   2016-10-27        Sacramento Kings       San Antonio Spurs          94
# 16   2016-10-27  Portland Trail Blazers             LA Clippers         106
# 17   2016-10-28         Toronto Raptors     Cleveland Cavaliers          91
# 18   2016-10-28           Brooklyn Nets          Indiana Pacers         103
# 19   2016-10-28         Detroit Pistons           Orlando Magic         108
# 20   2016-10-28   Oklahoma City Thunder            Phoenix Suns         113
# 21   2016-10-28              Miami Heat       Charlotte Hornets          91
# 22   2016-10-28        Dallas Mavericks         Houston Rockets          98
# 23   2016-10-28               Utah Jazz      Los Angeles Lakers          96
# 24   2016-10-28    New Orleans Pelicans   Golden State Warriors         114
# 25   2016-10-29      Philadelphia 76ers           Atlanta Hawks          72
# 26   2016-10-29       Charlotte Hornets          Boston Celtics          98
# 27   2016-10-29         New York Knicks       Memphis Grizzlies         111
# 28   2016-10-29     Cleveland Cavaliers           Orlando Magic         105
# 29   2016-10-29           Chicago Bulls          Indiana Pacers         118
# ...         ...                     ...                     ...         ...
# 1200 2017-04-09       Memphis Grizzlies         Detroit Pistons          90
# 1201 2017-04-09      Los Angeles Lakers  Minnesota Timberwolves         110
# 1202 2017-04-10      Philadelphia 76ers          Indiana Pacers         111
# 1203 2017-04-10          Boston Celtics           Brooklyn Nets         114
# 1204 2017-04-10              Miami Heat     Cleveland Cavaliers         124
# 1205 2017-04-10           Chicago Bulls           Orlando Magic         122
# 1206 2017-04-10         Milwaukee Bucks       Charlotte Hornets          89
# 1207 2017-04-10         Detroit Pistons      Washington Wizards         101
# 1208 2017-04-10  Portland Trail Blazers       San Antonio Spurs          99
# 1209 2017-04-10             LA Clippers         Houston Rockets         125
# 1210 2017-04-10   Golden State Warriors               Utah Jazz          99
# 1211 2017-04-11           Atlanta Hawks       Charlotte Hornets         103
# 1212 2017-04-11  Minnesota Timberwolves   Oklahoma City Thunder          98
# 1213 2017-04-11        Dallas Mavericks          Denver Nuggets          91
# 1214 2017-04-11      Los Angeles Lakers    New Orleans Pelicans         108
# 1215 2017-04-11        Sacramento Kings            Phoenix Suns         129
# 1216 2017-04-12           Orlando Magic         Detroit Pistons         113
# 1217 2017-04-12     Cleveland Cavaliers         Toronto Raptors          83
# 1218 2017-04-12          Boston Celtics         Milwaukee Bucks         112
# 1219 2017-04-12         New York Knicks      Philadelphia 76ers         114
# 1220 2017-04-12              Miami Heat      Washington Wizards         110
# 1221 2017-04-12           Chicago Bulls           Brooklyn Nets         112
# 1222 2017-04-12       Memphis Grizzlies        Dallas Mavericks          93
# 1223 2017-04-12         Houston Rockets  Minnesota Timberwolves         123
# 1224 2017-04-12   Oklahoma City Thunder          Denver Nuggets         105
# 1225 2017-04-12          Indiana Pacers           Atlanta Hawks         104
# 1226 2017-04-12               Utah Jazz       San Antonio Spurs         101
# 1227 2017-04-12             LA Clippers        Sacramento Kings         115
# 1228 2017-04-12   Golden State Warriors      Los Angeles Lakers         109
# 1229 2017-04-12  Portland Trail Blazers    New Orleans Pelicans         100
#
#       Away Score Winner
# 0             88   Home
# 1            104   Home
# 2            129   Away
# 3            108   Away
# 4            121   Home
# 5            117   Home
# 6             91   Home
# 7            107   Away
# 8             98   Home
# 9            107   Away
# 10           103   Away
# 11           113   Away
# 12           114   Home
# 13            99   Home
# 14            99   Home
# 15           102   Away
# 16           114   Away
# 17            94   Away
# 18            94   Home
# 19            82   Home
# 20           110   Home
# 21            97   Away
# 22           106   Away
# 23            89   Home
# 24           122   Away
# 25           104   Away
# 26           104   Away
# 27           104   Home
# 28            99   Home
# 29           101   Home
# ...          ...    ...
# 1200         103   Away
# 1201         109   Home
# 1202         120   Away
# 1203         105   Home
# 1204         121   Home
# 1205          75   Home
# 1206          79   Home
# 1207         105   Away
# 1208          98   Home
# 1209          96   Home
# 1210         105   Away
# 1211          76   Home
# 1212         100   Away
# 1213         109   Away
# 1214          96   Home
# 1215         104   Home
# 1216         109   Home
# 1217          98   Away
# 1218          94   Home
# 1219         113   Home
# 1220         102   Home
# 1221          73   Home
# 1222         100   Away
# 1223         118   Home
# 1224         111   Away
# 1225          86   Home
# 1226          97   Home
# 1227          95   Home
# 1228          94   Home
# 1229         103   Away
#
# [1230 rows x 6 columns]

# %% [markdown]
# ### Clean the results DataFrame
# Change time to integers (after the `start_date`). Keep index values of winners and losers, so it's easy to simulate the season. Also keep track of whether it's a conference or division game

# %%
# store the start date, store dates by integers representing days after the start_date 
start_date = results['Date'][0]
results['Day Number']=((results['Date']-start_date)/np.timedelta64(1, 'D')).astype(int)
results = results.drop('Date', axis=1)

# Associate (home and away) teams with their index
results = results.merge(teams_divisions, left_on='Home Team', right_on='Team_Name', how='left')
results=results.rename(columns = {'Division_id':'Home_Division_id', 'team_id':'Home_team_id','Conference_id':'Home_Conference_id'})
del results['Team_Name']
results = results.merge(teams_divisions, left_on='Away Team', right_on='Team_Name', how='left')
results=results.rename(columns = {'Division_id':'Away_Division_id', 'team_id':'Away_team_id','Conference_id':'Away_Conference_id'})
del results['Team_Name']

# Since home and away is irrelevant in this question, store teams by win/loss/margin of victory
results.loc[results['Winner'] == 'Home','Winning_team_id'] = results['Home_team_id']
results.loc[results['Winner'] == 'Home','Losing_team_id'] = results['Away_team_id']
results.loc[results['Winner'] == 'Home','Margin'] = (results['Home Score'] - results['Away Score']).astype(int)
results.loc[results['Winner'] == 'Away','Winning_team_id'] = results['Away_team_id']
results.loc[results['Winner'] == 'Away','Losing_team_id'] = results['Home_team_id']
results.loc[results['Winner'] == 'Away','Margin'] = (results['Away Score'] - results['Home Score']).astype(int)
results['Winning_team_id'] = results['Winning_team_id'].astype(int)
results['Losing_team_id'] = results['Losing_team_id'].astype(int)
results['Margin'] = results['Margin'].astype(int)

#drop irrelevant columns
results=results.drop(['Home_team_id','Away_team_id','Home Team', 'Away Team','Home Score', 'Away Score', 'Winner', 'Home Team', 'Away Team'], axis=1)

# Associate conference and division games with conference title, if not division (or conference) game, put `None`
results.loc[results['Away_Conference_id']==results['Home_Conference_id'], 'Conference'] = results['Home_Conference_id']
results.loc[results['Home_Conference_id']!=results['Away_Conference_id'], 'Conference'] = None
results.loc[results['Home_Division_id']==results['Away_Division_id'], 'Division'] = results['Home_Division_id']
results.loc[results['Home_Division_id']!=results['Away_Division_id'], 'Division'] = None

results=results.drop(['Home_Conference_id','Home_Division_id','Away_Conference_id','Away_Division_id'], axis=1)

results
# Out:
#       Day Number  Winning_team_id  Losing_team_id  Margin Conference  \
# 0              0                6               2      29       East
# 1              0               18              19       9       West
# 2              0               29              20      29       West
# 3              1               12              13      12       East
# 4              1                8              25       9       None
# 5              1                0               1       5       East
# 6              1                4               7      18       East
# 7              1               11               9      11       East
# 8              1               27              16       4       West
# 9              1               15              28       5       West
# 10             1               17               3       6       None
# 11             1               24              23      19       West
# 12             1               22              26       6       West
# 13             2               10              14      15       East
# 14             2                5               0       6       East
# 15             2               29              24       8       West
# 16             2               21              18       8       West
# 17             3                6               4       3       East
# 18             3                1               8       9       East
# 19             3                7              13      26       East
# 20             3               17              23       3       West
# 21             3               11              12       6       East
# 22             3               26              25       8       West
# 23             3               19              22       7       West
# 24             3               20              28       8       West
# 25             4               10               3      32       East
# 26             4                0              11       6       East
# 27             4                2              27       7       None
# 28             4                6              13       6       East
# 29             4                5               8      17       East
# ...          ...              ...             ...     ...        ...
# 1200         166                7              27      13       None
# 1201         166               22              16       1       West
# 1202         167                8               3       9       East
# 1203         167                0               1       9       East
# 1204         167               12               6       3       East
# 1205         167                5              13      47       East
# 1206         167                9              11      10       East
# 1207         167               14               7       4       East
# 1208         167               18              29       1       West
# 1209         167               21              26      29       West
# 1210         167               19              20       6       West
# 1211         168               10              11      27       East
# 1212         168               17              16       2       West
# 1213         168               15              25      18       West
# 1214         168               22              28      12       West
# 1215         168               24              23      25       West
# 1216         169               13               7       4       East
# 1217         169                4               6      15       East
# 1218         169                0               9      18       East
# 1219         169                2               3       1       East
# 1220         169               12              14       8       East
# 1221         169                5               1      39       East
# 1222         169               25              27       7       West
# 1223         169               26              16       5       West
# 1224         169               15              17       6       West
# 1225         169                8              10      18       East
# 1226         169               19              29       4       West
# 1227         169               21              24      20       West
# 1228         169               20              22      15       West
# 1229         169               28              18       3       West
#
#        Division
# 0          None
# 1     Northwest
# 2          None
# 3     Southeast
# 4          None
# 5      Atlantic
# 6          None
# 7          None
# 8          None
# 9          None
# 10         None
# 11      Pacific
# 12         None
# 13    Southeast
# 14         None
# 15         None
# 16         None
# 17         None
# 18         None
# 19         None
# 20         None
# 21    Southeast
# 22    Southwest
# 23         None
# 24         None
# 25         None
# 26         None
# 27         None
# 28         None
# 29      Central
# ...         ...
# 1200       None
# 1201       None
# 1202       None
# 1203   Atlantic
# 1204       None
# 1205       None
# 1206       None
# 1207       None
# 1208       None
# 1209       None
# 1210       None
# 1211  Southeast
# 1212  Northwest
# 1213       None
# 1214       None
# 1215    Pacific
# 1216       None
# 1217       None
# 1218       None
# 1219   Atlantic
# 1220  Southeast
# 1221       None
# 1222  Southwest
# 1223       None
# 1224  Northwest
# 1225       None
# 1226       None
# 1227    Pacific
# 1228    Pacific
# 1229       None
#
# [1230 rows x 6 columns]

# %%
eastern_conference = [[0 for i in range(15)] for i in range(15)]
western_conference = [[0 for i in range(15)] for i in range(15)]
for i in range(results.shape[0]):
    if results.iloc[i]['Conference'] == 'East':
        eastern_conference[results.iloc[i]['Winning_team_id']][results.iloc[i]['Losing_team_id']] += 1
        eastern_conference[results.iloc[i]['Losing_team_id']][results.iloc[i]['Winning_team_id']] += 1
    if results.iloc[i]['Conference'] == 'East':
        western_conference[results.iloc[i]['Winning_team_id']-15][results.iloc[i]['Losing_team_id']-15] += 1
        western_conference[results.iloc[i]['Losing_team_id']-15][results.iloc[i]['Winning_team_id']-15] += 1

# %% [markdown]
# # Create Team objects, and simulate and check after each game

# %% [markdown]
# `Team` object, which allows for easy sorting of standings, etc.

# %%
def check_confs_elimination(conf1, conf2, day):
    check_conf_elimination(conf1, day)
    check_conf_elimination(conf2, day)

def check_conf_elimination(conf, day):
    eighth_place = sorted(conf)[-8]
    for team in conf:
        team.check_elimination(eighth_place, day)
        
class Team(object):
    def __init__(self, num):
        self.team_id = num
        self.wins=0
        self.possible_wins = 82
        self.conf_wins = 0
        self.poss_conf_wins = 52 #calculated from above data
        self.winning_margin = 0
        self.elim_day = -1
        self.eliminated = False
    
    def lose_game(self, frame):
        self.possible_wins -= 1
        if frame['Conference']:
            self.poss_conf_wins -= 1
        #if frame['Division']:
            #self.possible_division_wins -= 1
    
    def win_game(self, frame):
        self.wins += 1
        if frame['Conference']:
            self.conf_wins += 1
        
    def check_elimination(self, eighth_place_team, day):
        if (self.possible_wins < eighth_place_team.wins and not self.eliminated):
            self.eliminated = True
            self.elim_day = day
        elif (eighth_place_team.wins == self.possible_wins):
            if (self.poss_conf_wins < eighth_place_team.conf_wins and not self.eliminated):
                self.eliminated = True
                self.elim_day = day
            
    def __lt__(self, other):
        if self.wins < other.wins:
            return True
        elif self.wins == other.wins:
            if self.conf_wins < other.conf_wins:
                return True
        return False
    
    def __gt__(self, other):
        return not self.__lt__(other)
    
    def __eq__(self, other):
        return self.team_id == other.team_id
    
    def __neq__(self, other):
        return not self.__eq__(other)

# %%
eastern = [Team(i) for i in range(15)]
western = [Team(i+15) for i in range(15)]

for i in range(results.shape[0]):
    if results.iloc[i]['Winning_team_id'] < 15:
        winning_team = eastern[results.iloc[i]['Winning_team_id']]
    else:
        winning_team = western[results.iloc[i]['Winning_team_id']-15]
    winning_team.win_game(results.iloc[i])

    if results.iloc[i]['Losing_team_id'] < 15:
        losing_team = eastern[results.iloc[i]['Losing_team_id']]
    else:
        losing_team = western[results.iloc[i]['Losing_team_id']-15]
    losing_team.lose_game(results.iloc[i])
    
    check_confs_elimination(eastern, western, results.iloc[i]['Day Number'])
        
check_confs_elimination(eastern, western, results.iloc[-1]['Day Number'])

# %%
r = [0 for i in range(30)]
for team in eastern:
    r[team.team_id] = team.elim_day

for team in western:
    r[team.team_id] = team.elim_day
elim = pd.DataFrame(r, columns=["elim"])
elim['team_id'] = np.array([i for i in range(30)])
elim = elim.merge(teams_divisions, on='team_id', how='left')
elim.loc[elim['elim']!=-1, 'Date Eliminated'] = '\"=\"(start_date + pd.to_timedelta(elim['elim'], unit='D')).dt.strftime("%m/%d/%Y").astype(str)
elim.loc[elim['elim']==-1, 'Date Eliminated'] = "Playoffs"
elim = elim.sort_values(by=['Team_Name']).drop(['elim','team_id','Division_id','Conference_id'], axis=1).rename(columns={'Team_Name':"Team"})
elim
# Out:
#                       Team Date Eliminated
# 10           Atlanta Hawks        Playoffs
# 0           Boston Celtics        Playoffs
# 1            Brooklyn Nets      03/08/2017
# 11       Charlotte Hornets      04/08/2017
# 5            Chicago Bulls        Playoffs
# 6      Cleveland Cavaliers        Playoffs
# 25        Dallas Mavericks      04/01/2017
# 15          Denver Nuggets      04/09/2017
# 7          Detroit Pistons      04/08/2017
# 20   Golden State Warriors        Playoffs
# 26         Houston Rockets        Playoffs
# 8           Indiana Pacers        Playoffs
# 21             LA Clippers        Playoffs
# 22      Los Angeles Lakers      03/19/2017
# 27       Memphis Grizzlies        Playoffs
# 12              Miami Heat      04/12/2017
# 9          Milwaukee Bucks        Playoffs
# 16  Minnesota Timberwolves      04/01/2017
# 28    New Orleans Pelicans      04/02/2017
# 2          New York Knicks      03/29/2017
# 17   Oklahoma City Thunder        Playoffs
# 13           Orlando Magic      03/28/2017
# 3       Philadelphia 76ers      03/29/2017
# 23            Phoenix Suns      03/21/2017
# 18  Portland Trail Blazers        Playoffs
# 24        Sacramento Kings      03/30/2017
# 29       San Antonio Spurs        Playoffs
# 4          Toronto Raptors        Playoffs
# 19               Utah Jazz        Playoffs
# 14      Washington Wizards        Playoffs

# %%
elim.to_csv("./playoffs.csv", index=False)
